# %% [markdown]
# # Simples
#
# $$
#
# y = w_0 + w_1 \cdot x_1
#
# $$

# %% [markdown]
# # Múltipla
#
# $$
#
# y = \sum_{n=0}^n w_n \cdot x_n
#
# $$
#
# Admite _n_ variáveis para o cálculo da função de reta que define o valor de y, com menor erro possível, com base na métrica escolhida.
